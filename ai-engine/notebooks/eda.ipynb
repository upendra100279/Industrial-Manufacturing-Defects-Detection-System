# %% [markdown]
# # MVTec AD — Exploratory Data Analysis
# Use this notebook to inspect category samples, defect mask coverage, and class distribution before running `dataset.py`.

# %%
import cv2
import matplotlib.pyplot as plt
from pathlib import Path

category_dir = Path('../data/raw/mvtec_ad/bottle')
test_dir = category_dir / 'test'
print(sorted([d.name for d in test_dir.iterdir() if d.is_dir()]))
